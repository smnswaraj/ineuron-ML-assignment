# %%
n=9
for i in range(1,n+1):
    if i<=(n/2):
        for j in range(1,i+1):
            print("*",end=" ")
    if i>(n/2):
        for z in range(1,n-i+2):
            print("*",end=" ")
    print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
name= input("your name")
for i in name[::-1]:
    print(i,end="")
# Out:
#  your namesuman
# namus
